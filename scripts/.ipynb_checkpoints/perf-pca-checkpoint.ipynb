# %% [markdown]
# # NVPerf Principle Component Analysis
#
# In this notebook, we will be performing principle component analysis on runs of the most popular language models using Hugging Face.
#
# Later, this PCA will be compared to that of traditional GPU benchmarks, namely [rodinia](https://github.com/yuhc/gpu-rodinia).

# %%
from glob import glob
import os

import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Running and generating a report for each of the datasets
# !rm *.csv
for file in glob('../external/gpu-rodinia/cuda/**/run'):
    directory = file[:-4]

    os.system(f"cd {directory} && ncu --metrics sm__warps_active.avg.per_cycle_active,sm__warps_active.avg.pct_of_peak_sustained_active,sm__throughput.avg.pct_of_peak_sustained_elapsed,sm__maximum_warps_per_active_cycle_pct,sm__maximum_warps_avg_per_active_cycle,sm__cycles_active.avg,lts__throughput.avg.pct_of_peak_sustained_elapsed,launch__waves_per_multiprocessor,launch__thread_count,launch__shared_mem_per_block_static,launch__shared_mem_per_block_dynamic,launch__shared_mem_per_block_driver,launch__shared_mem_per_block,launch__shared_mem_config_size,launch__registers_per_thread,launch__occupancy_per_shared_mem_size,launch__occupancy_per_register_count,launch__occupancy_per_block_size,launch__occupancy_limit_warps,launch__occupancy_limit_shared_mem,launch__occupancy_limit_registers,launch__occupancy_limit_blocks,launch__grid_size,launch__func_cache_config,launch__block_size,l1tex__throughput.avg.pct_of_peak_sustained_active,gpu__time_duration.sum,gpu__compute_memory_throughput.avg.pct_of_peak_sustained_elapsed,gpc__cycles_elapsed.max,gpc__cycles_elapsed.avg.per_second,breakdown:sm__throughput.avg.pct_of_peak_sustained_elapsed,breakdown:gpu__compute_memory_throughput.avg.pct_of_peak_sustained_elapsed,launch__occupancy_per_cluster_size,launch__occupancy_cluster_pct,launch__occupancy_cluster_gpu_pct,launch__cluster_size,launch__cluster_scheduling_policy,launch__cluster_max_potential_size,launch__cluster_max_active,gpu__dram_throughput.avg.pct_of_peak_sustained_elapsed,dram__cycles_elapsed.avg.per_second --target-processes all -o out -f bash ./run && cd -")
    os.system(f"cd {directory} && ncu --import out.ncu-rep --csv > out.csv && cd -")
    os.system(f"cp {directory}/out.csv .")

    try:
        df = pd.read_csv('out.csv')
        df.to_csv(file.split("/")[-2] + ".csv", index=False)
    except:
        print("Failed to read", file)
    
    os.system("rm out.csv")

print("Done")
# Out:
# ==PROF== Connected to process 627598 (/p/archgpuprofiling/sim-pca/external/gpu-rodinia/cuda/backprop/backprop)
# ==PROF== Target process 627614 terminated before first instrumented API call.
# ==PROF== Target process 627615 terminated before first instrumented API call.
# ==PROF== Profiling "bpnn_layerforward_CUDA" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "bpnn_adjust_weights_cuda" - 1: 0%....50%....100% - 9 passes
# ==PROF== Disconnected from process 627598
# Random number generator seed: 7
# Input layer size : 197152
# Starting training kernel
# Performing GPU computation
# Training done
# ==PROF== Report: /p/archgpuprofiling/sim-pca/external/gpu-rodinia/cuda/backprop/out.ncu-rep
# /p/archgpuprofiling/sim-pca/scripts
# /p/archgpuprofiling/sim-pca/scripts
# ./run: line 1: 627744 Segmentation fault      ./hotspot 512 2 2 ../../data/hotspot/temp_512 ../../data/hotspot/power_512 output.out
# ==ERROR== The application returned an error code (139).
# ==WARNING== No kernels were profiled.
# ./run: line 1: ./kmeans: No such file or directory
# ==ERROR== The application returned an error code (127).
# ==WARNING== No kernels were profiled.
# ==PROF== Connected to process 627859 (/p/archgpuprofiling/sim-pca/external/gpu-rodinia/cuda/myocyte/myocyte.out)
# ==PROF== Target process 627907 terminated before first instrumented API call.
# ==PROF== Target process 627908 terminated before first instrumented API call.
# ==PROF== Profiling "kernel" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 1: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 2: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 3: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 4: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 5: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 6: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 7: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 8: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 9: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 10: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 11: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 12: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 13: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 14: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 15: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 16: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 17: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 18: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 19: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 20: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 21: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 22: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 23: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 24: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 25: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 26: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 27: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 28: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 29: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 30: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 31: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 32: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 33: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 34: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 35: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 36: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 37: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 38: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 39: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 40: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 41: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 42: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 43: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 44: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 45: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 46: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 47: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 48: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 49: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 50: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 51: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 52: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 53: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 54: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 55: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 56: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 57: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 58: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 59: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 60: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 61: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 62: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 63: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 64: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 65: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 66: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 67: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 68: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 69: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 70: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 71: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 72: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 73: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 74: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 75: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 76: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 77: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 78: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 79: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 80: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 81: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 82: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 83: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 84: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 85: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 86: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 87: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 88: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 89: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 90: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 91: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 92: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 93: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 94: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 95: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 96: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 97: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 98: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 99: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 100: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 101: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 102: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 103: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 104: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 105: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 106: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 107: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 108: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 109: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 110: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 111: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 112: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 113: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 114: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 115: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 116: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 117: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 118: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 119: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 120: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 121: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 122: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 123: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 124: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 125: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 126: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 127: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 128: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 129: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 130: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 131: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 132: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 133: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 134: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 135: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 136: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 137: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 138: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 139: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 140: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 141: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 142: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 143: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 144: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 145: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 146: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 147: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 148: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 149: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 150: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 151: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 152: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 153: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 154: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel" - 155: 0%....50%....100% - 9 passes
# ==PROF== Disconnected from process 627859
# The file was not opened for reading
# The file was not opened for reading
# STATUS: -1
# Time spent in different stages of the application:
# 0.000000000000 s, 0.000000000000 % : SETUP VARIABLES
# 3.832355976105 s, 3.292916774750 % : ALLOCATE CPU MEMORY AND GPU MEMORY
# 0.000708999985 s, 0.000609201728 % : READ DATA FROM FILES
# 112.548736572266 s, 96.706466674805 % : RUN COMPUTATION
# 0.000011000000 s, 0.000009451649 % : FREE MEMORY
# Total time:
# 116.381805419922 s
# ==PROF== Report: /p/archgpuprofiling/sim-pca/external/gpu-rodinia/cuda/myocyte/out.ncu-rep
# /p/archgpuprofiling/sim-pca/scripts
# /p/archgpuprofiling/sim-pca/scripts
# Error with AVI_open_input_file: avilib - Error opening AVI file
# REASON: No such file or directory
# WG size of kernel = 256
# ==ERROR== The application returned an error code (255).
# ==WARNING== No kernels were profiled.
# ./run: line 1: ./particlefilter_naive: No such file or directory
# ./run: line 2: ./particlefilter_float: No such file or directory
# ==ERROR== The application returned an error code (127).
# ==WARNING== No kernels were profiled.
# ==PROF== Connected to process 630374 (/p/archgpuprofiling/sim-pca/external/gpu-rodinia/cuda/gaussian/gaussian)
# ==PROF== Target process 630423 terminated before first instrumented API call.
# ==PROF== Target process 630424 terminated before first instrumented API call.
# ./run: line 1: 630374 Segmentation fault      ./gaussian -f ../../data/gaussian/matrix4.txt
# ==PROF== Connected to process 630430 (/p/archgpuprofiling/sim-pca/external/gpu-rodinia/cuda/gaussian/gaussian)
# ==PROF== Target process 630461 terminated before first instrumented API call.
# ==PROF== Target process 630462 terminated before first instrumented API call.
# ==PROF== Profiling "Fan1" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 1: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 2: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 3: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 4: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 5: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 6: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 7: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 8: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 9: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 10: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 11: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 12: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 13: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 14: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 15: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 16: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 17: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 18: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 19: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 20: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 21: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 22: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 23: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 24: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 25: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 26: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 27: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan1" - 28: 0%....50%....100% - 9 passes
# ==PROF== Profiling "Fan2" - 29: 0%....50%....100% - 9 passes
# ==PROF== Disconnected from process 630430
# WG size of kernel 1 = 512, WG size of kernel 2= 4 X 4
# Total Device found: 1
# Device Name 		 - NVIDIA H100 NVL
# **************************************
# Total Global Memory			 - 97521088 KB
# Shared memory available per block 	 - 48 KB
# Number of registers per thread block 	 - 65536
# Warp size in threads 			 - 32
# Memory Pitch 				 - 2147483647 bytes
# Maximum threads per block 		 - 1024
# Maximum Thread Dimension (block) 	 - 1024 1024 64
# Maximum Thread Dimension (grid) 	 - 2147483647 65535 65535
# Total constant memory 			 - 65536 bytes
# CUDA ver 				 - 9.0
# Clock rate 				 - 1785000 KHz
# Texture Alignment 			 - 512 bytes
# Device Overlap 				 - Allowed
# Number of Multi processors 		 - 132
#
# Create matrix internally in parse, size = 16
#
# Time total (including memory transfers)	22.554709 sec
# Time for CUDA kernels:	22.329993 sec
# ==PROF== Report: /p/archgpuprofiling/sim-pca/external/gpu-rodinia/cuda/gaussian/out.ncu-rep
# /p/archgpuprofiling/sim-pca/scripts
# /p/archgpuprofiling/sim-pca/scripts
# ./run: line 1: ./hybridsort: No such file or directory
# ==ERROR== The application returned an error code (127).
# ==WARNING== No kernels were profiled.
# ./run: line 1: ./lavaMD: No such file or directory
# ==ERROR== The application returned an error code (127).
# ==WARNING== No kernels were profiled.
# Error: The file was not opened
# ./run: line 1: 631114 Segmentation fault      ./3D 512 8 100 ../../data/hotspot3D/power_512x8 ../../data/hotspot3D/temp_512x8 output.out
# ==ERROR== The application returned an error code (139).
# ==WARNING== No kernels were profiled.
# ==PROF== Connected to process 631189 (/p/archgpuprofiling/sim-pca/external/gpu-rodinia/cuda/pathfinder/pathfinder)
# ==PROF== Target process 631203 terminated before first instrumented API call.
# ==PROF== Target process 631204 terminated before first instrumented API call.
# ==PROF== Profiling "dynproc_kernel" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "dynproc_kernel" - 1: 0%....50%....100% - 9 passes
# ==PROF== Profiling "dynproc_kernel" - 2: 0%....50%....100% - 9 passes
# ==PROF== Profiling "dynproc_kernel" - 3: 0%....50%....100% - 9 passes
# ==PROF== Profiling "dynproc_kernel" - 4: 0%....50%....100% - 9 passes
# ==PROF== Disconnected from process 631189
# ==PROF== Report: /p/archgpuprofiling/sim-pca/external/gpu-rodinia/cuda/pathfinder/out.ncu-rep
# /p/archgpuprofiling/sim-pca/scripts
# /p/archgpuprofiling/sim-pca/scripts
# ./run: line 1: usage:: command not found
# ./run: line 3: bin/mummergpu: No such file or directory
# ==ERROR== The application returned an error code (127).
# ==WARNING== No kernels were profiled.
# ./run: line 1: ./CUDA/leukocyte: No such file or directory
# ==ERROR== The application returned an error code (127).
# ==WARNING== No kernels were profiled.
# Reading File
# Error Reading graph file
# ==WARNING== No kernels were profiled.
# /p/archgpuprofiling/sim-pca/scripts
# error opening a db
# ==ERROR== The application returned an error code (1).
# ==WARNING== No kernels were profiled.
# ./run: line 1: There: command not found
# ./run: line 3: ./euler3d: No such file or directory
# ./run: line 4: ./euler3d: No such file or directory
# ./run: line 5: ./euler3d: No such file or directory
# ./run: line 7: replace: command not found
# ==PROF== Target process 631629 terminated before first instrumented API call.
# ==ERROR== The application returned an error code (127).
# ==WARNING== No kernels were profiled.
# ./run: line 1: ./b+tree.out: No such file or directory
# ==PROF== Target process 631697 terminated before first instrumented API call.
# ==ERROR== The application returned an error code (127).
# ==WARNING== No kernels were profiled.
# PARSEC Benchmark Suite
# read 65536 points
# ==PROF== Connected to process 631761 (/p/archgpuprofiling/sim-pca/external/gpu-rodinia/cuda/streamcluster/sc_gpu)
# ==PROF== Target process 631809 terminated before first instrumented API call.
# ==PROF== Target process 631810 terminated before first instrumented API call.
# ==PROF== Profiling "kernel_compute_cost" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 1: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 2: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 3: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 4: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 5: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 6: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 7: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 8: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 9: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 10: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 11: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 12: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 13: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 14: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 15: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 16: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 17: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 18: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 19: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 20: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 21: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 22: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 23: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 24: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 25: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 26: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 27: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 28: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 29: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 30: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 31: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 32: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 33: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 34: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 35: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 36: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 37: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 38: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 39: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 40: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 41: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 42: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 43: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 44: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 45: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 46: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 47: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 48: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 49: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 50: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 51: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 52: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 53: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 54: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 55: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 56: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 57: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 58: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 59: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 60: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 61: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 62: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 63: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 64: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 65: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 66: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 67: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 68: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 69: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 70: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 71: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 72: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 73: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 74: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 75: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 76: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 77: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 78: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 79: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 80: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 81: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 82: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 83: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 84: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 85: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 86: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 87: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 88: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 89: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 90: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 91: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 92: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 93: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 94: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 95: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 96: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 97: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 98: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 99: 0%....50%....100% - 9 passes
# ==PROF== Profiling "kernel_compute_cost" - 100:

# %%
dfs = []

for file in glob("*.csv"):
    df = pd.read_csv(file)
    base_name = os.path.splitext(file)[0]
    if len(df.columns) < 5:
        continue
    dfs.append(df)

# Concatenate all DataFrames
dfs = pd.concat(dfs, axis=0, ignore_index=True)
dfs = dfs.drop_duplicates(subset=["Kernel Name", "Metric Name"])
dfs['Metric Value'] = dfs['Metric Value'].apply(lambda x: str(x).replace(",", "") if isinstance(x, str) else x)
dfs
# Out:
#         ID  Process ID Process Name  Host Name  \
# 0        0      630430     gaussian  127.0.0.1
# 1        0      630430     gaussian  127.0.0.1
# 2        0      630430     gaussian  127.0.0.1
# 3        0      630430     gaussian  127.0.0.1
# 4        0      630430     gaussian  127.0.0.1
# ...     ..         ...          ...        ...
# 172615   0      631189   pathfinder  127.0.0.1
# 172616   0      631189   pathfinder  127.0.0.1
# 172617   0      631189   pathfinder  127.0.0.1
# 172618   0      631189   pathfinder  127.0.0.1
# 172619   0      631189   pathfinder  127.0.0.1
#
#                                               Kernel Name  Context  Stream  \
# 0                        Fan1(float *, float *, int, int)        1       7
# 1                        Fan1(float *, float *, int, int)        1       7
# 2                        Fan1(float *, float *, int, int)        1       7
# 3                        Fan1(float *, float *, int, int)        1       7
# 4                        Fan1(float *, float *, int, int)        1       7
# ...                                                   ...      ...     ...
# 172615  dynproc_kernel(int, int *, int *, int *, int, ...        1       7
# 172616  dynproc_kernel(int, int *, int *, int *, int, ...        1       7
# 172617  dynproc_kernel(int, int *, int *, int *, int, ...        1       7
# 172618  dynproc_kernel(int, int *, int *, int *, int, ...        1       7
# 172619  dynproc_kernel(int, int *, int *, int *, int, ...        1       7
#
#          Block Size    Grid Size  Device   CC                   Section Name  \
# 0       (512, 1, 1)    (1, 1, 1)       0  9.0  Command line profiler metrics
# 1       (512, 1, 1)    (1, 1, 1)       0  9.0  Command line profiler metrics
# 2       (512, 1, 1)    (1, 1, 1)       0  9.0  Command line profiler metrics
# 3       (512, 1, 1)    (1, 1, 1)       0  9.0  Command line profiler metrics
# 4       (512, 1, 1)    (1, 1, 1)       0  9.0  Command line profiler metrics
# ...             ...          ...     ...  ...                            ...
# 172615  (256, 1, 1)  (463, 1, 1)       0  9.0  Command line profiler metrics
# 172616  (256, 1, 1)  (463, 1, 1)       0  9.0  Command line profiler metrics
# 172617  (256, 1, 1)  (463, 1, 1)       0  9.0  Command line profiler metrics
# 172618  (256, 1, 1)  (463, 1, 1)       0  9.0  Command line profiler metrics
# 172619  (256, 1, 1)  (463, 1, 1)       0  9.0  Command line profiler metrics
#
#                                               Metric Name Metric Unit  \
# 0       dram__cycles_active.avg.pct_of_peak_sustained_...           %
# 1       fbpa__dram_sectors.avg.pct_of_peak_sustained_e...           %
# 2       l1tex__data_bank_reads.avg.pct_of_peak_sustain...           %
# 3       l1tex__data_bank_writes.avg.pct_of_peak_sustai...           %
# 4       l1tex__data_pipe_lsu_wavefronts.avg.pct_of_pea...           %
# ...                                                   ...         ...
# 172615             sm__maximum_warps_avg_per_active_cycle        warp
# 172616             sm__maximum_warps_per_active_cycle_pct           %
# 172617   sm__throughput.avg.pct_of_peak_sustained_elapsed           %
# 172618  sm__warps_active.avg.pct_of_peak_sustained_active           %
# 172619              sm__warps_active.avg.per_cycle_active        warp
#
#        Metric Value
# 0              0.04
# 1              0.04
# 2              0.00
# 3              0.00
# 4              0.01
# ...             ...
# 172615           64
# 172616          100
# 172617        21.17
# 172618        42.74
# 172619        27.36
#
# [756 rows x 15 columns]

# %%
# pivoting the data
df = dfs.pivot(index='Kernel Name', columns='Metric Name', values='Metric Value')

# df.columns = [column for column in df.columns]
# df['gpc__cycles_elapsed.max'] = df['gpc__cycles_elapsed.max'].apply(lambda x: int(str(x).replace(",", "")))
# df.reset_index(inplace=True)

for column in df.columns:
    # print(column)
    try:
        df[column] = df[column].astype(float)
    except:
        del df[column]

df.transpose()
# Out:
# Kernel Name                                         Fan1(float *, float *, int, int)  \
# Metric Name
# dram__cycles_active.avg.pct_of_peak_sustained_e...                              0.04
# dram__cycles_elapsed.avg.per_second                                             2.57
# fbpa__dram_sectors.avg.pct_of_peak_sustained_el...                              0.04
# gpc__cycles_elapsed.avg.per_second                                              1.06
# gpc__cycles_elapsed.max                                                      4306.00
# gpu__compute_memory_throughput.avg.pct_of_peak_...                             11.14
# gpu__dram_throughput.avg.pct_of_peak_sustained_...                              0.04
# gpu__time_duration.sum                                                          4.06
# idc__request_cycles_active.avg.pct_of_peak_sust...                              0.02
# l1tex__data_bank_reads.avg.pct_of_peak_sustaine...                              0.00
# l1tex__data_bank_writes.avg.pct_of_peak_sustain...                              0.00
# l1tex__data_pipe_lsu_wavefronts.avg.pct_of_peak...                              0.01
# l1tex__data_pipe_tex_wavefronts.avg.pct_of_peak...                              0.00
# l1tex__f_wavefronts.avg.pct_of_peak_sustained_e...                              0.00
# l1tex__lsu_writeback_active.avg.pct_of_peak_sus...                              0.00
# l1tex__lsuin_requests.avg.pct_of_peak_sustained...                              0.00
# l1tex__m_l1tex2xbar_req_cycles_active.avg.pct_o...                              0.05
# l1tex__m_xbar2l1tex_read_sectors.avg.pct_of_pea...                              0.00
# l1tex__m_xbar2l1tex_read_sectors_mem_dshared.av...                              0.00
# l1tex__tex_writeback_active.avg.pct_of_peak_sus...                              0.00
# l1tex__texin_sm2tex_req_cycles_active.avg.pct_o...                              0.16
# l1tex__throughput.avg.pct_of_peak_sustained_active                             78.64
# l1tex__tmain_requests.avg.pct_of_peak_sustained...                              0.00
# launch__block_size                                                            512.00
# launch__cluster_max_active                                                      0.00
# launch__cluster_max_potential_size                                              8.00
# launch__cluster_size                                                            0.00
# launch__grid_size                                                               1.00
# launch__occupancy_cluster_gpu_pct                                               0.00
# launch__occupancy_cluster_pct                                                   0.00
# launch__occupancy_limit_blocks                                                 32.00
# launch__occupancy_limit_registers                                               8.00
# launch__occupancy_limit_shared_mem                                             16.00
# launch__occupancy_limit_warps                                                   4.00
# launch__occupancy_per_block_size                                             3528.00
# launch__occupancy_per_cluster_size                                              0.00
# launch__occupancy_per_register_count                                         4288.00
# launch__occupancy_per_shared_mem_size                                        2144.00
# launch__registers_per_thread                                                   16.00
# launch__shared_mem_config_size                                                 16.38
# launch__shared_mem_per_block                                                    1.02
# launch__shared_mem_per_block_driver                                             1.02
# launch__shared_mem_per_block_dynamic                                            0.00
# launch__shared_mem_per_block_static                                             0.00
# launch__thread_count                                                          512.00
# launch__waves_per_multiprocessor                                                0.00
# lts__d_atomic_input_cycles_active.avg.pct_of_pe...                              0.00
# lts__d_sectors.avg.pct_of_peak_sustained_elapsed                                0.09
# lts__d_sectors_fill_device.avg.pct_of_peak_sust...                              0.01
# lts__d_sectors_fill_sysmem.avg.pct_of_peak_sust...                              0.00
# lts__lts2xbar_cycles_active.avg.pct_of_peak_sus...                              2.82
# lts__t_sectors.avg.pct_of_peak_sustained_elapsed                                3.72
# lts__t_tag_requests.avg.pct_of_peak_sustained_e...                             11.14
# lts__throughput.avg.pct_of_peak_sustained_elapsed                              12.64
# lts__xbar2lts_cycles_active.avg.pct_of_peak_sus...                              5.80
# sm__cycles_active.avg                                                           8.90
# sm__inst_executed.avg.pct_of_peak_sustained_ela...                              0.01
# sm__inst_executed_pipe_adu.avg.pct_of_peak_sust...                              0.03
# sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_...                              0.00
# sm__inst_executed_pipe_ipa.avg.pct_of_peak_sust...                              0.00
# sm__inst_executed_pipe_lsu.avg.pct_of_peak_sust...                              0.00
# sm__inst_executed_pipe_tex.avg.pct_of_peak_sust...                              0.00
# sm__inst_executed_pipe_uniform.avg.pct_of_peak_...                              0.00
# sm__inst_executed_pipe_xu.avg.pct_of_peak_susta...                              0.00
# sm__issue_active.avg.pct_of_peak_sustained_elapsed                              0.01
# sm__maximum_warps_avg_per_active_cycle                                         64.00
# sm__maximum_warps_per_active_cycle_pct                                        100.00
# sm__mio2rf_writeback_active.avg.pct_of_peak_sus...                              0.00
# sm__mio_inst_issued.avg.pct_of_peak_sustained_e...                              0.01
# sm__mio_pq_read_cycles_active.avg.pct_of_peak_s...                              0.00
# sm__mio_pq_write_cycles_active.avg.pct_of_peak_...                              0.00
# sm__pipe_alu_cycles_active.avg.pct_of_peak_sust...                              0.00
# sm__pipe_fma_cycles_active.avg.pct_of_peak_sust...                              0.00
# sm__pipe_fmaheavy_cycles_active.avg.pct_of_peak...                              0.00
# sm__pipe_fp64_cycles_active.avg.pct_of_peak_sus...                              0.00
# sm__pipe_shared_cycles_active.avg.pct_of_peak_s...                              0.00
# sm__pipe_tensor_cycles_active.avg.pct_of_peak_s...                              0.00
# sm__pipe_tensor_op_dmma_cycles_active.avg.pct_o...                              0.00
# sm__pipe_tma_cycles_active.avg.pct_of_peak_sust...                              0.00
# sm__throughput.avg.pct_of_peak_sustained_elapsed                                0.03
# sm__warps_active.avg.pct_of_peak_sustained_active                              12.09
# sm__warps_active.avg.per_cycle_active                                           7.74
#
# Kernel Name                                         Fan2(float *, float *, float *, int, int, int)  \
# Metric Name
# dram__cycles_active.avg.pct_of_peak_sustained_e...                                            0.03
# dram__cycles_elapsed.avg.per_second                                                           2.59
# fbpa__dram_sectors.avg.pct_of_peak_sustained_el...                                            0.03
# gpc__cycles_elapsed.avg.per_second                                                            1.07
# gpc__cycles_elapsed.max                                                                    4822.00
# gpu__compute_memory_throughput.avg.pct_of_peak_...                                            9.95
# gpu__dram_throughput.avg.pct_of_peak_sustained_...                                            0.03
# gpu__time_duration.sum                                                                        4.51
# idc__request_cycles_active.avg.pct_of_peak_sust...                                            0.03
# l1tex__data_bank_reads.avg.pct_of_peak_sustaine...                                            0.00
# l1tex__data_bank_writes.avg.pct_of_peak_sustain...                                            0.00
# l1tex__data_pipe_lsu_wavefronts.avg.pct_of_peak...                                            0.03
# l1tex__data_pipe_tex_wavefronts.avg.pct_of_peak...                                            0.00
# l1tex__f_wavefronts.avg.pct_of_peak_sustained_e...                                            0.00
# l1tex__lsu_writeback_active.avg.pct_of_peak_sus...                                            0.01
# l1tex__lsuin_requests.avg.pct_of_peak_sustained...                                            0.02
# l1tex__m_l1tex2xbar_req_cycles_active.avg.pct_o...                                            0.07
# l1tex__m_xbar2l1tex_read_sectors.avg.pct_of_pea...                                            0.01
# l1tex__m_xbar2l1tex_read_sectors_mem_dshared.av...                                            0.00
# l1tex__tex_writeback_active.avg.pct_of_peak_sus...                                            0.00
# l1tex__texin_sm2tex_req_cycles_active.avg.pct_o...                                            0.15
# l1tex__throughput.avg.pct_of_peak_sustained_active                                            4.14
# l1tex__tmain_requests.avg.pct_of_peak_sustained...                                            0.00
# launch__block_size                                                                           16.00
# launch__cluster_max_active                                                                    0.00
# launch__cluster_max_potential_size                                                            8.00
# launch__cluster_size                                                                          0.00
# launch__grid_size                                                                            16.00
# launch__occupancy_cluster_gpu_pct                                                             0.00
# launch__occupancy_cluster_pct                                                                 0.00
# launch__occupancy_limit_blocks                                                               32.00
# launch__occupancy_limit_registers                                                            84.00
# launch__occupancy_limit_shared_mem                                                           32.00
# launch__occupancy_limit_warps                                                                64.00
# launch__occupancy_per_block_size                                                           3670.00
# launch__occupancy_per_cluster_size                                                            0.00
# launch__occupancy_per_register_count                                                       4512.00
# launch__occupancy_per_shared_mem_size                                                       312.00
# launch__registers_per_thread                                                                 20.00
# launch__shared_mem_config_size                                                               32.77
# launch__shared_mem_per_block                                                                  1.02
# launch__shared_mem_per_block_driver                                                           1.02
# launch__shared_mem_per_block_dynamic                                                          0.00
# launch__shared_mem_per_block_static                                                           0.00
# launch__thread_count                                                                        256.00
# launch__waves_per_multiprocessor                                                              0.00
# lts__d_atomic_input_cycles_active.avg.pct_of_pe...                                            0.00
# lts__d_sectors.avg.pct_of_peak_sustained_elapsed                                              0.07
# lts__d_sectors_fill_device.avg.pct_of_peak_sust...                                            0.01
# lts__d_sectors_fill_sysmem.avg.pct_of_peak_sust...                                            0.00
# lts__lts2xbar_cycles_active.avg.pct_of_peak_sus...                                            2.53
# lts__t_sectors.avg.pct_of_peak_sustained_elapsed                                              3.33
# lts__t_tag_requests.avg.pct_of_peak_sustained_e...                                            9.95
# lts__throughput.avg.pct_of_peak_sustained_elapsed                                            11.19
# lts__xbar2lts_cycles_active.avg.pct_of_peak_sus...                                            5.12
# sm__cycles_active.avg                                                                       169.20
# sm__inst_executed.avg.pct_of_peak_sustained_ela...                                            0.03
# sm__inst_executed_pipe_adu.avg.pct_of_peak_sust...                                            0.04
# sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_...                                            0.00
# sm__inst_executed_pipe_ipa.avg.pct_of_peak_sust...                                            0.00
# sm__inst_executed_pipe_lsu.avg.pct_of_peak_sust...                                            0.02
# sm__inst_executed_pipe_tex.avg.pct_of_peak_sust...                                            0.00
# sm__inst_executed_pipe_uniform.avg.pct_of_peak_...                                            0.00
# sm__inst_executed_pipe_xu.avg.pct_of_peak_susta...                                            0.00
# sm__issue_active.avg.pct_of_peak_sustained_elapsed                                            0.03
# sm__maximum_warps_avg_per_active_cycle                                                       32.00
# sm__maximum_warps_per_active_cycle_pct                                                       50.00
# sm__mio2rf_writeback_active.avg.pct_of_peak_sus...                                            0.01
# sm__mio_inst_issued.avg.pct_of_peak_sustained_e...                                            0.02
# sm__mio_pq_read_cycles_active.avg.pct_of_peak_s...                                            0.00
# sm__mio_pq_write_cycles_active.avg.pct_of_peak_...                                            0.00
# sm__pipe_alu_cycles_active.avg.pct_of_peak_sust...                                            0.01
# sm__pipe_fma_cycles_active.avg.pct_of_peak_sust...                                            0.01
# sm__pipe_fmaheavy_cycles_active.avg.pct_of_peak...                                            0.02
# sm__pipe_fp64_cycles_active.avg.pct_of_peak_sus...                                            0.00
# sm__pipe_shared_cycles_active.avg.pct_of_peak_s...                                            0.00
# sm__pipe_tensor_cycles_active.avg.pct_of_peak_s...                                            0.00
# sm__pipe_tensor_op_dmma_cycles_active.avg.pct_o...                                            0.00
# sm__pipe_tma_cycles_active.avg.pct_of_peak_sust...                                            0.00
# sm__throughput.avg.pct_of_peak_sustained_elapsed                                              0.04
# sm__warps_active.avg.pct_of_peak_sustained_active                                             1.56
# sm__warps_active.avg.per_cycle_active                                                         1.00
#
# Kernel Name                                         bpnn_adjust_weights_cuda(float *, int, float *, int, float *, float *)  \
# Metric Name
# dram__cycles_active.avg.pct_of_peak_sustained_e...                                              31.84
# dram__cycles_elapsed.avg.per_second                                                              2.61
# fbpa__dram_sectors.avg.pct_of_peak_sustained_el...                                              35.65
# gpc__cycles_elapsed.avg.per_second                                                               1.08
# gpc__cycles_elapsed.max                                                                      25331.00
# gpu__compute_memory_throughput.avg.pct_of_peak_...                                              61.61
# gpu__dram_throughput.avg.pct_of_peak_sustained_...                                              35.65
# gpu__time_duration.sum                                                                          23.49
# idc__request_cycles_active.avg.pct_of_peak_sust...                                              29.92
# l1tex__data_bank_reads.avg.pct_of_peak_sustaine...                                               9.13
# l1tex__data_bank_writes.avg.pct_of_peak_sustain...                                               6.34
# l1tex__data_pipe_lsu_wavefronts.avg.pct_of_peak...                                              55.13
# l1tex__data_pipe_tex_wavefronts.avg.pct_of_peak...                                               0.00
# l1tex__f_wavefronts.avg.pct_of_peak_sustained_e...                                               0.00
# l1tex__lsu_writeback_active.avg.pct_of_peak_sus...                                              27.07
# l1tex__lsuin_requests.avg.pct_of_peak_sustained...                                              32.52
# l1tex__m_l1tex2xbar_req_cycles_active.avg.pct_o...                                              45.13
# l1tex__m_xbar2l1tex_read_sectors.avg.pct_of_pea...                                               6.77
# l1tex__m_xbar2l1tex_read_sectors_mem_dshared.av...                                               0.00
# l1tex__tex_writeback_active.avg.pct_of_peak_sus...                                               0.00
# l1tex__texin_sm2tex_req_cycles_active.avg.pct_o...                                               0.03
# l1tex__throughput.avg.pct_of_peak_sustained_active                                              64.83
# l1tex__tmain_requests.avg.pct_of_peak_sustained...                                               0.00
# launch__block_size                                                                             256.00
# launch__cluster_max_active                                                                       0.00
# launch__cluster_max_potential_size                                                               8.00
# launch__cluster_size                                                                             0.00
# launch__grid_size                                                                            12322.00
# launch__occupancy_cluster_gpu_pct                                                                0.00
# launch__occupancy_cluster_pct                                                                    0.00
# launch__occupancy_limit_blocks                                                                  32.00
# launch__occupancy_limit_registers                                                                8.00
# launch__occupancy_limit_shared_mem                                                              32.00
# launch__occupancy_limit_warps                                                                    8.00
# launch__occupancy_per_block_size                                                              3670.00
# launch__occupancy_per_cluster_size                                                               0.00
# launch__occupancy_per_register_count                                                          5504.00
# launch__occupancy_per_shared_mem_size                                                         1696.00
# launch__registers_per_thread                                                                    30.00
# launch__shared_mem_config_size                                                                  32.77
# launch__shared_mem_per_block                                                                     1.02
# launch__shared_mem_per_block_driver                                                              1.02
# launch__shared_mem_per_block_dynamic                                                             0.00
# launch__shared_mem_per_block_static                                                              0.00
# launch__thread_count                                                                       3154432.00
# launch__waves_per_multiprocessor                                                                11.67
# lts__d_atomic_input_cycles_active.avg.pct_of_pe...                                               0.00
# lts__d_sectors.avg.pct_of_peak_sustained_elapsed                                                39.59
# lts__d_sectors_fill_device.avg.pct_of_peak_sust...                                              32.81
# lts__d_sectors_fill_sysmem.avg.pct_of_peak_sust...                                               0.00
# lts__lts2xbar_cycles_active.avg.pct_of_peak_sus...                                              17.69
# lts__t_sectors.avg.pct_of_peak_sustained_elapsed                                                36.59
# lts__t_tag_requests.avg.pct_of_peak_sustained_e...                                              43.11
# lts__throughput.avg.pct_of_peak_sustained_elapsed                                               80.15
# lts__xbar2lts_cycles_active.avg.pct_of_peak_sus...                                              61.61
# sm__cycles_active.avg                                                                        21481.06
# sm__inst_executed.avg.pct_of_peak_sustained_ela...                                              36.96
# sm__inst_executed_pipe_adu.avg.pct_of_peak_sust...                                              41.74
# sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_...                                               2.96
# sm__inst_executed_pipe_ipa.avg.pct_of_peak_sust...                                               0.00
# sm__inst_executed_pipe_lsu.avg.pct_of_peak_sust...                                              32.52
# sm__inst_executed_pipe_tex.avg.pct_of_peak_sust...                                               0.00
# sm__inst_executed_pipe_uniform.avg.pct_of_peak_...                                               2.96
# sm__inst_executed_pipe_xu.avg.pct_of_peak_susta...                                              53.22
# sm__issue_active.avg.pct_of_peak_sustained_elapsed                                              37.08
# sm__maximum_warps_avg_per_active_cycle                                                          64.00
# sm__maximum_warps_per_active_cycle_pct                                                         100.00
# sm__mio2rf_writeback_active.avg.pct_of_peak_sus...                                              11.09
# sm__mio_inst_issued.avg.pct_of_peak_sustained_e...                                              26.70
# sm__mio_pq_read_cycles_active.avg.pct_of_peak_s...                                               5.91
# sm__mio_pq_write_cycles_active.avg.pct_of_peak_...                                               5.91
# sm__pipe_alu_cycles_active.avg.pct_of_peak_sust...                                               4.43
# sm__pipe_fma_cycles_active.avg.pct_of_peak_sust...                                               7.39
# sm__pipe_fmaheavy_cycles_active.avg.pct_of_peak...                                              14.78
# sm__pipe_fp64_cycles_active.avg.pct_of_peak_sus...                                              10.35
# sm__pipe_shared_cycles_active.avg.pct_of_peak_s...                                              10.35
# sm__pipe_tensor_cycles_active.avg.pct_of_peak_s...                                               0.00
# sm__pipe_tensor_op_dmma_cycles_active.avg.pct_o...                                               0.00
# sm__pipe_tma_cycles_active.avg.pct_of_peak_sust...                                               0.00
# sm__throughput.avg.pct_of_peak_sustained_elapsed                                                53.22
# sm__warps_active.avg.pct_of_peak_sustained_active                                               84.72
# sm__warps_active.avg.per_cycle_active                                                           54.22
#
# Kernel Name                                         bpnn_layerforward_CUDA(float *, float *, float *, float *, int, int)  \
# Metric Name
# dram__cycles_active.avg.pct_of_peak_sustained_e...                                              10.59
# dram__cycles_elapsed.avg.per_second                                                              2.61
# fbpa__dram_sectors.avg.pct_of_peak_sustained_el...                                              11.75
# gpc__cycles_elapsed.avg.per_second                                                               1.08
# gpc__cycles_elapsed.max                                                                      36068.00
# gpu__compute_memory_throughput.avg.pct_of_peak_...                                              61.30
# gpu__dram_throughput.avg.pct_of_peak_sustained_...                                              11.75
# gpu__time_duration.sum                                                                          33.41
# idc__request_cycles_active.avg.pct_of_peak_sust...                                              16.83
# l1tex__data_bank_reads.avg.pct_of_peak_sustaine...                                               6.44
# l1tex__data_bank_writes.avg.pct_of_peak_sustain...                                               5.44
# l1tex__data_pipe_lsu_wavefronts.avg.pct_of_peak...                                              61.30
# l1tex__data_pipe_tex_wavefronts.avg.pct_of_peak...                                               0.00
# l1tex__f_wavefronts.avg.pct_of_peak_sustained_e...                                               0.00
# l1tex__lsu_writeback_active.avg.pct_of_peak_sus...                                              24.50
# l1tex__lsuin_requests.avg.pct_of_peak_sustained...                                              51.80
# l1tex__m_l1tex2xbar_req_cycles_active.avg.pct_o...                                              15.30
# l1tex__m_xbar2l1tex_read_sectors.avg.pct_of_pea...                                               2.46
# l1tex__m_xbar2l1tex_read_sectors_mem_dshared.av...                                               0.00
# l1tex__tex_writeback_active.avg.pct_of_peak_sus...                                               0.00
# l1tex__texin_sm2tex_req_cycles_active.avg.pct_o...                                               0.02
# l1tex__throughput.avg.pct_of_peak_sustained_active                                              68.40
# l1tex__tmain_requests.avg.pct_of_peak_sustained...                                               0.00
# launch__block_size                                                                             256.00
# launch__cluster_max_active                                                                       0.00
# launch__cluster_max_potential_size                                                               8.00
# launch__cluster_size                                                                             0.00
# launch__grid_size                                                                            12322.00
# launch__occupancy_cluster_gpu_pct                                                                0.00
# launch__occupancy_cluster_pct                                                                    0.00
# launch__occupancy_limit_blocks                                                                  32.00
# launch__occupancy_limit_registers                                                               10.00
# launch__occupancy_limit_shared_mem                                                              30.00
# launch__occupancy_limit_warps                                                                    8.00
# launch__occupancy_per_block_size                                                              3656.00
# launch__occupancy_per_cluster_size                                                               0.00
# launch__occupancy_per_register_count                                                          5504.00
# launch__occupancy_per_shared_mem_size                                                         5440.00
# launch__registers_per_thread                                                                    18.00
# launch__shared_mem_config_size                                                                  65.54
# launch__shared_mem_per_block                                                                     2.11
# launch__shared_mem_per_block_driver                                                              1.02
# launch__shared_mem_per_block_dynamic                                                             0.00
# launch__shared_mem_per_block_static                                                              1.09
# launch__thread_count                                                                       3154432.00
# launch__waves_per_multiprocessor                                                                11.67
# lts__d_atomic_input_cycles_active.avg.pct_of_pe...                                               0.00
# lts__d_sectors.avg.pct_of_peak_sustained_elapsed                                                13.80
# lts__d_sectors_fill_device.avg.pct_of_peak_sust...                                              11.75
# lts__d_sectors_fill_sysmem.avg.pct_of_peak_sust...                                               0.00
# lts__lts2xbar_cycles_active.avg.pct_of_peak_sus...                                               6.56
# lts__t_sectors.avg.pct_of_peak_sustained_elapsed                                                13.25
# lts__t_tag_requests.avg.pct_of_peak_sustained_e...                                              14.63
# lts__throughput.avg.pct_of_peak_sustained_elapsed                                               33.19
# lts__xbar2lts_cycles_active.avg.pct_of_peak_sus...                                              21.47
# sm__cycles_active.avg                                                                        32299.36
# sm__inst_executed.avg.pct_of_peak_sustained_ela...                                              67.86
# sm__inst_executed_pipe_adu.avg.pct_of_peak_sust...                                              58.27
# sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_...                                               4.14
# sm__inst_executed_pipe_ipa.avg.pct_of_peak_sust...                                               0.00
# sm__inst_executed_pipe_lsu.avg.pct_of_peak_sust...                                              51.80
# sm__inst_executed_pipe_tex.avg.pct_of_peak_sust...                                               0.00
# sm__inst_executed_pipe_uniform.avg.pct_of_peak_...                                               5.18
# sm__inst_executed_pipe_xu.avg.pct_of_peak_susta...                                              49.73
# sm__issue_active.avg.pct_of_peak_sustained_elapsed                                              68.02
# sm__maximum_warps_avg_per_active_cycle                                                          64.00
# sm__maximum_warps_per_active_cycle_pct                                                         100.00
# sm__mio2rf_writeback_active.avg.pct_of_peak_sus...                                               8.68
# sm__mio_inst_issued.avg.pct_of_peak_sustained_e...                                              40.47
# sm__mio_pq_read_cycles_active.avg.pct_of_peak_s...                                              14.24
# sm__mio_pq_write_cycles_active.avg.pct_of_peak_...                                              14.24
# sm__pipe_alu_cycles_active.avg.pct_of_peak_sust...                                              35.22
# sm__pipe_fma_cycles_active.avg.pct_of_peak_sust...                                              23.83
# sm__pipe_fmaheavy_cycles_active.avg.pct_of_peak...                                              43.14
# sm__pipe_fp64_cycles_active.avg.pct_of_peak_sus...                                               0.00
# sm__pipe_shared_cycles_active.avg.pct_of_peak_s...                                               1.04
# sm__pipe_tensor_cycles_active.avg.pct_of_peak_s...                                               1.04
# sm__pipe_tensor_op_dmma_cycles_active.avg.pct_o...                                               0.00
# sm__pipe_tma_cycles_active.avg.pct_of_peak_sust...                                               0.00
# sm__throughput.avg.pct_of_peak_sustained_elapsed                                                68.02
# sm__warps_active.avg.pct_of_peak_sustained_active                                               89.09
# sm__warps_active.avg.per_cycle_active                                                           57.02
#
# Kernel Name                                         dynproc_kernel(int, int *, int *, int *, int, int, int, int)  \
# Metric Name
# dram__cycles_active.avg.pct_of_peak_sustained_e...                                              10.85
# dram__cycles_elapsed.avg.per_second                                                              2.61
# fbpa__dram_sectors.avg.pct_of_peak_sustained_el...                                              12.04
# gpc__cycles_elapsed.avg.per_second                                                               1.08
# gpc__cycles_elapsed.max                                                                      20815.00
# gpu__compute_memory_throughput.avg.pct_of_peak_...                                              20.73
# gpu__dram_throughput.avg.pct_of_peak_sustained_...                                              12.04
# gpu__time_duration.sum                                                                          19.30
# idc__request_cycles_active.avg.pct_of_peak_sust...                                               7.40
# l1tex__data_bank_reads.avg.pct_of_peak_sustaine...                                               6.32
# l1tex__data_bank_writes.avg.pct_of_peak_sustain...                                               3.89
# l1tex__data_pipe_lsu_wavefronts.avg.pct_of_peak...                                              20.73
# l1tex__data_pipe_tex_wavefronts.avg.pct_of_peak...                                               0.00
# l1tex__f_wavefronts.avg.pct_of_peak_sustained_e...                                               0.00
# l1tex__lsu_writeback_active.avg.pct_of_peak_sus...                                              13.94
# l1tex__lsuin_requests.avg.pct_of_peak_sustained...                                              19.28
# l1tex__m_l1tex2xbar_req_cycles_active.avg.pct_o...                                               2.60
# l1tex__m_xbar2l1tex_read_sectors.avg.pct_of_pea...                                               2.69
# l1tex__m_xbar2l1tex_read_sectors_mem_dshared.av...                                               0.00
# l1tex__tex_writeback_active.avg.pct_of_peak_sus...                                               0.00
# l1tex__texin_sm2tex_req_cycles_active.avg.pct_o...                                               0.03
# l1tex__throughput.avg.pct_of_peak_sustained_active                                              25.60
# l1tex__tmain_requests.avg.pct_of_peak_sustained...                                               0.00
# launch__block_size                                                                             256.00
# launch__cluster_max_active                                                                       0.00
# launch__cluster_max_potential_size                                                               8.00
# launch__cluster_size                                                                             0.00
# launch__grid_size                                                                              463.00
# launch__occupancy_cluster_gpu_pct                                                                0.00
# launch__occupancy_cluster_pct                                                                    0.00
# launch__occupancy_limit_blocks                                                                  32.00
# launch__occupancy_limit_registers                                                               10.00
# launch__occupancy_limit_shared_mem                                                              21.00
# launch__occupancy_limit_warps                                                                    8.00
# launch__occupancy_per_block_size                                                              3593.00
# launch__occupancy_per_cluster_size                                                               0.00
# launch__occupancy_per_register_count                                                          5504.00
# launch__occupancy_per_shared_mem_size                                                         5440.00
# launch__registers_per_thread                                                                    17.00
# launch__shared_mem_config_size                                                                  65.54
# launch__shared_mem_per_block                                                                     3.07
# launch__shared_mem_per_block_driver                                                              1.02
# launch__shared_mem_per_block_dynamic                                                             0.00
# launch__shared_mem_per_block_static                                                              2.05
# launch__thread_count                                                                        118528.00
# launch__waves_per_multiprocessor                                                                 0.44
# lts__d_atomic_input_cycles_active.avg.pct_of_pe...                                               0.00
# lts__d_sectors.avg.pct_of_peak_sustained_elapsed                                                 9.62
# lts__d_sectors_fill_device.avg.pct_of_peak_sust...                                              12.04
# lts__d_sectors_fill_sysmem.avg.pct_of_peak_sust...                                               0.00
# lts__lts2xbar_cycles_active.avg.pct_of_peak_sus...                                               7.25
# lts__t_sectors.avg.pct_of_peak_sustained_elapsed                                                 7.56
# lts__t_tag_requests.avg.pct_of_peak_sustained_e...                                               8.89
# lts__throughput.avg.pct_of_peak_sustained_elapsed                                               18.80
# lts__xbar2lts_cycles_active.avg.pct_of_peak_sus...                                               6.32
# sm__cycles_active.avg                                                                        16850.03
# sm__inst_executed.avg.pct_of_peak_sustained_ela...                                              21.10
# sm__inst_executed_pipe_adu.avg.pct_of_peak_sust...                                              18.73
# sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_...                                               0.17
# sm__inst_executed_pipe_ipa.avg.pct_of_peak_sust...                                               0.00
# sm__inst_executed_pipe_lsu.avg.pct_of_peak_sust...                                              19.28
# sm__inst_executed_pipe_tex.avg.pct_of_peak_sust...                                               0.00
# sm__inst_executed_pipe_uniform.avg.pct_of_peak_...                                               2.83
# sm__inst_executed_pipe_xu.avg.pct_of_peak_susta...                                               0.00
# sm__issue_active.avg.pct_of_peak_sustained_elapsed                                              21.17
# sm__maximum_warps_avg_per_active_cycle                                                          64.00
# sm__maximum_warps_per_active_cycle_pct                                                         100.00
# sm__mio2rf_writeback_active.avg.pct_of_peak_sus...                                               4.31
# sm__mio_inst_issued.avg.pct_of_peak_sustained_e...                                              14.32
# sm__mio_pq_read_cycles_active.avg.pct_of_peak_s...                                               5.53
# sm__mio_pq_write_cycles_active.avg.pct_of_peak_...                                               5.53
# sm__pipe_alu_cycles_active.avg.pct_of_peak_sust...                                              14.56
# sm__pipe_fma_cycles_active.avg.pct_of_peak_sust...                                               4.38
# sm__pipe_fmaheavy_cycles_active.avg.pct_of_peak...                                               8.76
# sm__pipe_fp64_cycles_active.avg.pct_of_peak_sus...                                               0.00
# sm__pipe_shared_cycles_active.avg.pct_of_peak_s...                                               0.00
# sm__pipe_tensor_cycles_active.avg.pct_of_peak_s...                                               0.00
# sm__pipe_tensor_op_dmma_cycles_active.avg.pct_o...                                               0.00
# sm__pipe_tma_cycles_active.avg.pct_of_peak_sust...                                               0.00
# sm__throughput.avg.pct_of_peak_sustained_elapsed                                                21.17
# sm__warps_active.avg.pct_of_peak_sustained_active                                               42.74
# sm__warps_active.avg.per_cycle_active                                                           27.36
#
# Kernel Name                                         kernel(int, float *, float *, float *, float *)  \
# Metric Name
# dram__cycles_active.avg.pct_of_peak_sustained_e...                                             0.06
# dram__cycles_elapsed.avg.per_second                                                            2.62
# fbpa__dram_sectors.avg.pct_of_peak_sustained_el...                                             0.06
# gpc__cycles_elapsed.avg.per_second                                                             1.08
# gpc__cycles_elapsed.max                                                                    64074.00
# gpu__compute_memory_throughput.avg.pct_of_peak_...                                             0.79
# gpu__dram_throughput.avg.pct_of_peak_sustained_...                                             0.06
# gpu__time_duration.sum                                                                        59.39
# idc__request_cycles_active.avg.pct_of_peak_sust...                                             0.00
# l1tex__data_bank_reads.avg.pct_of_peak_sustaine...                                             0.00
# ...
# l1tex__texin_sm2tex_req_cycles_active.avg.pct_o...                                               0.07
# l1tex__throughput.avg.pct_of_peak_sustained_active                                              12.61
# l1tex__tmain_requests.avg.pct_of_peak_sustained...                                               0.00
# launch__block_size                                                                              16.00
# launch__cluster_max_active                                                                       0.00
# launch__cluster_max_potential_size                                                               8.00
# launch__cluster_size                                                                             0.00
# launch__grid_size                                                                                1.00
# launch__occupancy_cluster_gpu_pct                                                                0.00
# launch__occupancy_cluster_pct                                                                    0.00
# launch__occupancy_limit_blocks                                                                  32.00
# launch__occupancy_limit_registers                                                               64.00
# launch__occupancy_limit_shared_mem                                                              40.00
# launch__occupancy_limit_warps                                                                   64.00
# launch__occupancy_per_block_size                                                              3670.00
# launch__occupancy_per_cluster_size                                                               0.00
# launch__occupancy_per_register_count                                                          4512.00
# launch__occupancy_per_shared_mem_size                                                         1282.00
# launch__registers_per_thread                                                                    32.00
# launch__shared_mem_config_size                                                                 135.17
# launch__shared_mem_per_block                                                                     3.20
# launch__shared_mem_per_block_driver                                                              1.02
# launch__shared_mem_per_block_dynamic                                                             0.00
# launch__shared_mem_per_block_static                                                              2.18
# launch__thread_count                                                                            16.00
# launch__waves_per_multiprocessor                                                                 0.00
# lts__d_atomic_input_cycles_active.avg.pct_of_pe...                                               0.00
# lts__d_sectors.avg.pct_of_peak_sustained_elapsed                                                 0.10
# lts__d_sectors_fill_device.avg.pct_of_peak_sust...                                               0.01
# lts__d_sectors_fill_sysmem.avg.pct_of_peak_sust...                                               0.00
# lts__lts2xbar_cycles_active.avg.pct_of_peak_sus...                                               1.18
# lts__t_sectors.avg.pct_of_peak_sustained_elapsed                                                 1.54
# lts__t_tag_requests.avg.pct_of_peak_sustained_e...                                               4.61
# lts__throughput.avg.pct_of_peak_sustained_elapsed                                                5.22
# lts__xbar2lts_cycles_active.avg.pct_of_peak_sus...                                               2.62
# sm__cycles_active.avg                                                                           55.53
# sm__inst_executed.avg.pct_of_peak_sustained_ela...                                               0.01
# sm__inst_executed_pipe_adu.avg.pct_of_peak_sust...                                               0.01
# sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_...                                               0.01
# sm__inst_executed_pipe_ipa.avg.pct_of_peak_sust...                                               0.00
# sm__inst_executed_pipe_lsu.avg.pct_of_peak_sust...                                               0.02
# sm__inst_executed_pipe_tex.avg.pct_of_peak_sust...                                               0.00
# sm__inst_executed_pipe_uniform.avg.pct_of_peak_...                                               0.00
# sm__inst_executed_pipe_xu.avg.pct_of_peak_susta...                                               0.00
# sm__issue_active.avg.pct_of_peak_sustained_elapsed                                               0.01
# sm__maximum_warps_avg_per_active_cycle                                                          32.00
# sm__maximum_warps_per_active_cycle_pct                                                          50.00
# sm__mio2rf_writeback_active.avg.pct_of_peak_sus...                                               0.00
# sm__mio_inst_issued.avg.pct_of_peak_sustained_e...                                               0.01
# sm__mio_pq_read_cycles_active.avg.pct_of_peak_s...                                               0.01
# sm__mio_pq_write_cycles_active.avg.pct_of_peak_...                                               0.01
# sm__pipe_alu_cycles_active.avg.pct_of_peak_sust...                                               0.00
# sm__pipe_fma_cycles_active.avg.pct_of_peak_sust...                                               0.00
# sm__pipe_fmaheavy_cycles_active.avg.pct_of_peak...                                               0.00
# sm__pipe_fp64_cycles_active.avg.pct_of_peak_sus...                                               0.00
# sm__pipe_shared_cycles_active.avg.pct_of_peak_s...                                               0.00
# sm__pipe_tensor_cycles_active.avg.pct_of_peak_s...                                               0.00
# sm__pipe_tensor_op_dmma_cycles_active.avg.pct_o...                                               0.00
# sm__pipe_tma_cycles_active.avg.pct_of_peak_sust...                                               0.00
# sm__throughput.avg.pct_of_peak_sustained_elapsed                                                 0.02
# sm__warps_active.avg.pct_of_peak_sustained_active                                                1.56
# sm__warps_active.avg.per_cycle_active                                                            1.00
#
# Kernel Name                                         needle_cuda_shared_2(int *, int *, int, int, int, int)
# Metric Name
# dram__cycles_active.avg.pct_of_peak_sustained_e...                                               0.99
# dram__cycles_elapsed.avg.per_second                                                              2.60
# fbpa__dram_sectors.avg.pct_of_peak_sustained_el...                                               1.09
# gpc__cycles_elapsed.avg.per_second                                                               1.07
# gpc__cycles_elapsed.max                                                                      10911.00
# gpu__compute_memory_throughput.avg.pct_of_peak_...                                               6.33
# gpu__dram_throughput.avg.pct_of_peak_sustained_...                                               1.09
# gpu__time_duration.sum                                                                          10.18
# idc__request_cycles_active.avg.pct_of_peak_sust...                                               0.12
# l1tex__data_bank_reads.avg.pct_of_peak_sustaine...                                               0.25
# l1tex__data_bank_writes.avg.pct_of_peak_sustain...                                               0.18
# l1tex__data_pipe_lsu_wavefronts.avg.pct_of_peak...                                               6.33
# l1tex__data_pipe_tex_wavefronts.avg.pct_of_peak...                                               0.00
# l1tex__f_wavefronts.avg.pct_of_peak_sustained_e...                                               0.00
# l1tex__lsu_writeback_active.avg.pct_of_peak_sus...                                               1.44
# l1tex__lsuin_requests.avg.pct_of_peak_sustained...                                               1.99
# l1tex__m_l1tex2xbar_req_cycles_active.avg.pct_o...                                               0.86
# l1tex__m_xbar2l1tex_read_sectors.avg.pct_of_pea...                                               0.14
# l1tex__m_xbar2l1tex_read_sectors_mem_dshared.av...                                               0.00
# l1tex__tex_writeback_active.avg.pct_of_peak_sus...                                               0.00
# l1tex__texin_sm2tex_req_cycles_active.avg.pct_o...                                               0.06
# l1tex__throughput.avg.pct_of_peak_sustained_active                                               9.77
# l1tex__tmain_requests.avg.pct_of_peak_sustained...                                               0.00
# launch__block_size                                                                              16.00
# launch__cluster_max_active                                                                       0.00
# launch__cluster_max_potential_size                                                               8.00
# launch__cluster_size                                                                             0.00
# launch__grid_size                                                                              127.00
# launch__occupancy_cluster_gpu_pct                                                                0.00
# launch__occupancy_cluster_pct                                                                    0.00
# launch__occupancy_limit_blocks                                                                  32.00
# launch__occupancy_limit_registers                                                               64.00
# launch__occupancy_limit_shared_mem                                                              40.00
# launch__occupancy_limit_warps                                                                   64.00
# launch__occupancy_per_block_size                                                              3670.00
# launch__occupancy_per_cluster_size                                                               0.00
# launch__occupancy_per_register_count                                                          4512.00
# launch__occupancy_per_shared_mem_size                                                         1282.00
# launch__registers_per_thread                                                                    32.00
# launch__shared_mem_config_size                                                                 135.17
# launch__shared_mem_per_block                                                                     3.20
# launch__shared_mem_per_block_driver                                                              1.02
# launch__shared_mem_per_block_dynamic                                                             0.00
# launch__shared_mem_per_block_static                                                              2.18
# launch__thread_count                                                                          2032.00
# launch__waves_per_multiprocessor                                                                 0.03
# lts__d_atomic_input_cycles_active.avg.pct_of_pe...                                               0.00
# lts__d_sectors.avg.pct_of_peak_sustained_elapsed                                                 0.98
# lts__d_sectors_fill_device.avg.pct_of_peak_sust...                                               1.06
# lts__d_sectors_fill_sysmem.avg.pct_of_peak_sust...                                               0.00
# lts__lts2xbar_cycles_active.avg.pct_of_peak_sus...                                               1.47
# lts__t_sectors.avg.pct_of_peak_sustained_elapsed                                                 2.15
# lts__t_tag_requests.avg.pct_of_peak_sustained_e...                                               5.28
# lts__throughput.avg.pct_of_peak_sustained_elapsed                                                7.09
# lts__xbar2lts_cycles_active.avg.pct_of_peak_sus...                                               3.39
# sm__cycles_active.avg                                                                         7062.91
# sm__inst_executed.avg.pct_of_peak_sustained_ela...                                               1.46
# sm__inst_executed_pipe_adu.avg.pct_of_peak_sust...                                               0.76
# sm__inst_executed_pipe_cbu_pred_on_any.avg.pct_...                                               0.81
# sm__inst_executed_pipe_ipa.avg.pct_of_peak_sust...                                               0.00
# sm__inst_executed_pipe_lsu.avg.pct_of_peak_sust...                                               1.99
# sm__inst_executed_pipe_tex.avg.pct_of_peak_sust...                                               0.00
# sm__inst_executed_pipe_uniform.avg.pct_of_peak_...                                               0.15
# sm__inst_executed_pipe_xu.avg.pct_of_peak_susta...                                               0.00
# sm__issue_active.avg.pct_of_peak_sustained_elapsed                                               1.53
# sm__maximum_warps_avg_per_active_cycle                                                          32.00
# sm__maximum_warps_per_active_cycle_pct                                                          50.00
# sm__mio2rf_writeback_active.avg.pct_of_peak_sus...                                               0.36
# sm__mio_inst_issued.avg.pct_of_peak_sustained_e...                                               1.19
# sm__mio_pq_read_cycles_active.avg.pct_of_peak_s...                                               1.11
# sm__mio_pq_write_cycles_active.avg.pct_of_peak_...                                               1.11
# sm__pipe_alu_cycles_active.avg.pct_of_peak_sust...                                               0.56
# sm__pipe_fma_cycles_active.avg.pct_of_peak_sust...                                               0.22
# sm__pipe_fmaheavy_cycles_active.avg.pct_of_peak...                                               0.43
# sm__pipe_fp64_cycles_active.avg.pct_of_peak_sus...                                               0.00
# sm__pipe_shared_cycles_active.avg.pct_of_peak_s...                                               0.00
# sm__pipe_tensor_cycles_active.avg.pct_of_peak_s...                                               0.00
# sm__pipe_tensor_op_dmma_cycles_active.avg.pct_o...                                               0.00
# sm__pipe_tma_cycles_active.avg.pct_of_peak_sust...                                               0.00
# sm__throughput.avg.pct_of_peak_sustained_elapsed                                                 1.99
# sm__warps_active.avg.pct_of_peak_sustained_active                                                1.56
# sm__warps_active.avg.per_cycle_active                                                            1.00

# %%
# Scaling and performing PCA
scaler = StandardScaler()
pca = PCA(n_components=2)

scaled_data = scaler.fit_transform(df)
principal_components = pca.fit_transform(scaled_data)

# Create a DataFrame with the principal components
# pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3079453/4151688759.py in ?()
#       1 # Scaling and performing PCA
#       2 scaler = StandardScaler()
#       3 pca = PCA(n_components=2)
#       4
# ----> 5 scaled_data = scaler.fit_transform(df)
#       6 principal_components = pca.fit_transform(scaled_data)
#       7
#       8 # Create a DataFrame with the principal components
#
# /p/archgpuprofiling/.poetry/virtualenvs/sim-pca-c6jnvBLi-py3.10/lib/python3.10/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     311     @wraps(f)
#     312     def wrapped(self, X, *args, **kwargs):
# --> 313         data_to_wrap = f(self, X, *args, **kwargs)
#     314         if isinstance(data_to_wrap, tuple):
#     315             # only wrap the first output for cross decomposition
#     316             return_tuple = (
#
# /p/archgpuprofiling/.poetry/virtualenvs/sim-pca-c6jnvBLi-py3.10/lib/python3.10/site-packages/sklearn/base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
#    1100             # fit method of arity 2 (supervised transformation)
#    1101             return self.fit(X, y, **fit_params).transform(X)
#
# /p/archgpuprofiling/.poetry/virtualenvs/sim-pca-c6jnvBLi-py3.10/lib/python3.10/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     874             Fitted scaler.
#     875         """
#     876         # Reset internal state before fitting
#     877         self._reset()
# --> 878         return self.partial_fit(X, y, sample_weight)
#
# /p/archgpuprofiling/.poetry/virtualenvs/sim-pca-c6jnvBLi-py3.10/lib/python3.10/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# /p/archgpuprofiling/.poetry/virtualenvs/sim-pca-c6jnvBLi-py3.10/lib/python3.10/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     910         self : object
#     911             Fitted scaler.
#     912         """
#     913         first_call = not hasattr(self, "n_samples_seen_")
# --> 914         X = self._validate_data(
#     915             X,
#     916             accept_sparse=("csr", "csc"),
#     917             dtype=FLOAT_DTYPES,
#
# /p/archgpuprofiling/.poetry/virtualenvs/sim-pca-c6jnvBLi-py3.10/lib/python3.10/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# /p/archgpuprofiling/.poetry/virtualenvs/sim-pca-c6jnvBLi-py3.10/lib/python3.10/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# /p/archgpuprofiling/.poetry/virtualenvs/sim-pca-c6jnvBLi-py3.10/lib/python3.10/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     747         # Use NumPy API to support order
#     748         if copy is True:
#     749             array = numpy.array(array, order=order, dtype=dtype)
#     750         else:
# --> 751             array = numpy.asarray(array, order=order, dtype=dtype)
#     752
#     753         # At this point array is a NumPy ndarray. We convert it to an array
#     754         # container that is consistent with the input's namespace.
#
# /p/archgpuprofiling/.poetry/virtualenvs/sim-pca-c6jnvBLi-py3.10/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'PolicySpread'

# %%
plt.scatter(pca_df['PC1'], pca_df['PC2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Rodinia')
plt.show()
